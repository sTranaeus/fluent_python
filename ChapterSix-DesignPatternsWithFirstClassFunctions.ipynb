# %% [markdown]
# In software engineering, a software design pattern is a general, reusable solution to a commonly occurring problem within a given context in software design.
#
# https://en.wikipedia.org/wiki/Software_design_pattern
#
# Design patterns are langauge independent, though they don't necessarily apply to every language.

# %% [markdown]
# To create __abstract__ classes in python use the abc module
#
# abc.ABC, and abc.abstractmethod decorator

# %%
hasattr(int, '__abs__')
# Out:
# False

# %%
int.__dict__
# Out:
# mappingproxy({'__abs__': <slot wrapper '__abs__' of 'int' objects>,
#               '__add__': <slot wrapper '__add__' of 'int' objects>,
#               '__and__': <slot wrapper '__and__' of 'int' objects>,
#               '__bool__': <slot wrapper '__bool__' of 'int' objects>,
#               '__ceil__': <method '__ceil__' of 'int' objects>,
#               '__divmod__': <slot wrapper '__divmod__' of 'int' objects>,
# ...

# %% [markdown]
# It can often prove better to just use a typical function, than a single method class. Functions are generally more lightweight that a user defined class and any instances of it.

# %% [markdown]
# __really__ experiment with using functions just as ordinary objects in Python. It's very powerful.

# %% [markdown]
# Use inspect.getmembers(object) to get the attribtues of an object

# %% [markdown]
# Implementing an interface with a single method is better done through a standard Python function, than an actual class - thanks to first class functions.

# %%
#inspect.isfunction(func) returns True if func is a user defined function
inspect.getmembers(int)
# Out:
# [('__abs__', <slot wrapper '__abs__' of 'int' objects>),
#  ('__add__', <slot wrapper '__add__' of 'int' objects>),
#  ('__and__', <slot wrapper '__and__' of 'int' objects>),
#  ('__bool__', <slot wrapper '__bool__' of 'int' objects>),
#  ('__ceil__', <method '__ceil__' of 'int' objects>),
#  ('__class__', type),
#  ('__delattr__', <slot wrapper '__delattr__' of 'object' objects>),
#  ('__dir__', <method '__dir__' of 'object' objects>),
#  ('__divmod__', <slot wrapper '__divmod__' of 'int' objects>),
#  ('__doc__',
# ...

# %%
globals()
locals()
# Out:
# {'In': ['',
#   'hasattr(int, )',
#   'int.__attributes__',
#   'inspect(int)',
#   'import inspect',
#   'inspect(int)',
#   'from inspect import Signature',
#   'Signature(int)',
#   'int.__dict__',
#   "hasattr(int, '__abs__')",
#   "hasattr(int, '__ab__')",
#   'globals()',
#   'globals()\nlocals()'],
#  'Out': {8: mappingproxy({'__abs__': <slot wrapper '__abs__' of 'int' objects>,
#                 '__add__': <slot wrapper '__add__' of 'int' objects>,
#                 '__and__': <slot wrapper '__and__' of 'int' objects>,
#                 '__bool__': <slot wrapper '__bool__' of 'int' objects>,
#                 '__ceil__': <method '__ceil__' of 'int' objects>,
#                 '__divmod__': <slot wrapper '__divmod__' of 'int' objects>,
# ...
